# %%
import numpy as np

#Forward mode, automatic differentiation class

##############################################
######       Arithmetic Operators       ######
##############################################
class forwardAD:
    def __init__(self, val, der_vector = None, numvar = 1, idx = 0):
        self.val = val
        if der_vector is None:
            der_vector = np.zeros(int(numvar))
            der_vector[idx] = 1
            self.der = der_vector
        else:
            self.der = der_vector
        #self.seed = np.floor(np.rand(1)*100000)

    #Overloaded addition
    def __add__(self, other):

        #For adding of the same class, add derivatives
        try:
            out_val = self.val + other.val
            out_der = self.der + other.der

        #For adding a float, keep derivative
        except AttributeError:
            out_val = self.val + other
            out_der = self.der

        return forwardAD(out_val, out_der)

    #Overloaded subtraction
    def __sub__(self, other):

        #For subtracting of the same class, subtract derivatives
        try:
            out_val = self.val - other.val
            out_der = self.der - other.der

        #For subtracting a float, keep derivative
        except AttributeError:
            out_val = self.val - other
            out_der = self.der

        return forwardAD(out_val, out_der)

    #Overloaded multiplication
    def __mul__(self, other):

        #For multiplying the same class, use product rule
        try:
            out_val = self.val * other.val
            out_der = self.der * other.val + self.val * other.der

        #For multiplying a float, multiply the value
        except AttributeError:
            out_val = self.val * other
            out_der = self.der * other

        return forwardAD(out_val, out_der)


    #Overloaded division
    def __truediv__(self, other):

        #For dividing the same class, use quotient rule
        try:
            out_val = self.val / other.val
            out_der = (self.der * other.val - self.val * other.der)/(other.val ** 2.0)

        #For dividing a float, divide the value
        except AttributeError:
            out_val = self.val / other
            out_der = self.der / other

        return forwardAD(out_val, out_der)
    
    def __truediv__(self, other):

        #For dividing the same class, use quotient rule
        try:
            out_val = self.val / other.val
            out_der = (self.der * other.val - self.val * other.der)/(other.val ** 2.0)

        #For dividing a float, divide the value
        except AttributeError:
            out_val = self.val / other
            out_der = self.der / other

        return forwardAD(out_val, out_der)

    #Overloaded power
    def __pow__(self, other):

    #For power to same class, use logarithmic differentiation
        try:
            out_val = self.val ** other.val
            out_der = (other.der * np.log(self.val) + other.val * (self.der / self.val)) * (self.val ** other.val)

        #For raising to a float, do power rule
        except AttributeError:
            out_val = self.val ** other
            out_der = self.der * other * self.val **(other - 1.0)

        return forwardAD(out_val, out_der)

    ### Reversed Operations ###

    # Addition is commutative
    def __radd__(self, other):
        return self.__add__(other)

    # Reverse subtraction
    def __rsub__(self, other):

        #If another of same type, then reverse order of subtraction
        try:
            out_val = other.val - self.val
            out_der = other.der - self.der

        #If a float, then reverse order subtract
        except AttributeError:
            out_val = other - self.val
            out_der = -1.0 * self.der

        return forwardAD(out_val, out_der)

    #Multiplication is commutative
    def __rmul__(self, other):
        return self.__mul__(other)

    #Reverse division
    def __rtruediv__(self, other):
        #For dividing the same class, use reversed quotient rule
        try:
            out_val = other.val / self.val
            out_der = (other.der * self.val - other.val * self.der)/(self.val ** 2.0)

        #For dividing a float, take derivative of f**(-1) using power rule
        except AttributeError:
            out_val = other / self.val
            out_der = (-1.0) * other * self.der / (self.val**2.0)

        return forwardAD(out_val, out_der)

    #Reverse power
    def __rpow__(self, other):

        #If base is same class, do logarithmic differentiation
        try:
            out_val = other.val ** self.val
            out_der = (self.der * np.log(other.val) + self.val * (other.der / other.val)) * (other.val ** self.val)

        #If base is a float, then b^x derivative rule
        except AttributeError:
            out_val = other ** self.val
            out_der = other ** self.val * self.der * np.log(other)

        return forwardAD(out_val, out_der)
    
    ##############################################
    ######       Comparison Operators       ######
    ##############################################
    
    def __lt__(self, other):
        try:
            return np.less(self.val, other.val) and np.less(self.der, other.der)
        except AttributeError:
            return np.less(self.val, other)
    
    def __gt__(self, other):
        try:
            return np.greater(self.val, other.val) and np.greater(self.der, other.der)
        except AttributeError:
            return np.greater(self.val, other)
            
    def __le__(self, other):
        try:
            return np.less_equal(self.val, other.val) and np.less_equal(self.der, other.der)
        except AttributeError:
            return np.less_equal(self.val, other)

    def __ge__(self, other):
        try:
            return np.greater_equal(self.val, other.val) and np.greater_equal(self.der, other.der)
        except AttributeError:
            return np.greater_equal(self.val, other)

    def __eq__(self, other):
        try:
            return np.array_equal(self.val, other.val) and np.array_equal(self.der, other.der)
        except AttributeError:
            return np.array_equal(self.val, other)
            
    #def __req__(self, other):
    #    return self.__eq__(other)
    
    def __ne__(self, other):
        try:
            return not np.array_equal(self.val, other.val) and not np.array_equal(self.der, other.der)
        except AttributeError:
            return not np.array_equal(self.val, other)
            
    #def __rne__(self, other):
    #    return self.__ne__(other)


##############################################
######       Elementary Functions       ######
##############################################

#For getting an 'e'
class e(forwardAD):
    def __init__(self, val=np.exp(1), der=0.0):
        self.val = val
        self.der = der

#For getting a log, defaults to natural log
class log(forwardAD):
    def __init__(self, inputs, base = np.exp(1)):

        #For getting log of variable expression, log is derivative/val
        try:
            self.val = np.log(inputs.val)/np.log(base)
            self.der = inputs.der / inputs.val

        #For log of float, use numpy.log
        except AttributeError:
            self.val = np.log(inputs) / np.log(base)
            self.der = 0.0


#####  Trignometric Functions #####

#For getting a sine
class sin(forwardAD):
    def __init__(self, inputs):

        #For getting sine of variable expression, der = in.der * cos(in.val)
        try:
            self.val = np.sin(inputs.val)
            self.der = inputs.der * np.cos(inputs.val)

        #For sine of float, use numpy.sin
        except AttributeError:
            self.val = np.sin(inputs)
            self.der = 0.0


#For getting a cosine
class cos(forwardAD):
    def __init__(self, inputs):

        #For getting cosine of variable expression, der = -in.der * sin(in.val)
        try:
            self.val = np.cos(inputs.val)
            self.der = -inputs.der * np.sin(inputs.val)

        #For cosine of float, use numpy.cos
        except AttributeError:
            self.val = np.cos(inputs)
            self.der = 0.0


#For getting a tangent
class tan(forwardAD):
    def __init__(self, inputs):

        #For getting tangent of variable expression, der = in.der * (1 + tan(in.val)^2)
        try:
            self.val = np.tan(inputs.val)
            self.der = inputs.der * (1 + np.tan(inputs.val)**2)

        #For tanget of float, use numpy.tan
        except AttributeError:
            self.val = np.tan(inputs)
            self.der = 0.0


##### Inverse Trignometric Functions #####

#For getting a inverse sine
class arcsin(forwardAD):
    def __init__(self, inputs):

        #For getting arcsin of variable expression, der = in.der * (1/sqrt(1-inputs.val**2))
        try:
            self.val = np.arcsin(inputs.val)
            self.der = inputs.der * (1/np.sqrt(1-inputs.val**2))

        #For arcsin of float, use numpy.arcsin
        except AttributeError:
            self.val = np.arcsin(inputs)
            self.der = 0.0


#For getting a inverse cosine
class arccos(forwardAD):
    def __init__(self, inputs):

        #For getting arccos of variable expression, der = -in.der * sin(in.val)
        try:
            self.val = np.arccos(inputs.val)
            self.der = -inputs.der * (1/np.sqrt(1-inputs.val**2))

        #For arccos of float, use numpy.arccos
        except AttributeError:
            self.val = np.arccos(inputs)
            self.der = 0.0


#For getting a inverse tangent
class arctan(forwardAD):
    def __init__(self, inputs):

        #For getting arctan of variable expression, der = in.der * (1 / in.val^2)
        try:
            self.val = np.arctan(inputs.val)
            self.der = inputs.der * (1/(1+inputs.val**2))

        #For arctan of float, use numpy.arctan
        except AttributeError:
            self.val = np.arctan(inputs)
            self.der = 0.0


##### Hyperbolic Trignometric Functions #####

#For getting a hyperbolic sine
class sinh(forwardAD):
    def __init__(self, inputs):

        #For getting sinh of variable expression, der = in.der * sinh(in.val)
        try:
            self.val = np.sinh(inputs.val)
            self.der = np.cosh(inputs.val)

        #For sine of float, use numpy.tan
        except AttributeError:
            self.val = np.sinh(inputs)
            self.der = 0.0


#For getting a hyperbolic cosh
class cosh(forwardAD):
    def __init__(self, inputs):

        #For getting cosh of variable expression, der = in.der * sinh(in.val)
        try:
            self.val = np.cosh(inputs.val)
            self.der = np.sinh(inputs.val)

        #For sine of float, use numpy.cos
        except AttributeError:
            self.val = np.cosh(inputs)
            self.der = 0.0

#For getting a hyperbolic tangent
class tanh(forwardAD):
    def __init__(self, inputs):

        #For getting tangent of variable expression, der = in.der * (1 + tan(in.val)^2)
        try:
            self.val = np.tanh(inputs.val)
            self.der = inputs.der * (1 - np.tanh(inputs.val)**2)

        #For sine of float, use numpy.tan
        except AttributeError:
            self.val = np.tanh(inputs)
            self.der = 0.0
class vector_func: #vector_func(f1, f2, ...)
    def __init__(self, *args): #  
        jacobian_array = []
        values_array = []
        for function in args: 
                jacobian_array.append(function.der)
                values_array.append(function.val)
        self.jacobian_array = np.array(jacobian_array)
        self.values_array = np.array(values_array)

    def jacobian(self):
        return self.jacobian_array
    def values(self):
        return self.values_array

# %%
cur_x = forwardAD(3) # The algorithm starts at x=3

rate = 0.01 # Learning rate
precision = 0.000001 #This tells us when to stop the algorithm
previous_step_size = 1 #
max_iters = 10000 # maximum number of iterations
iters = 0 #iteration counter

# %%
while previous_step_size > precision and iters < max_iters:
    prev_x = cur_x #Store current x value in prev_x
    f = (prev_x + 5)**2 # gradient
    cur_x = cur_x - rate * f.der #Grad descent
    previous_step_size = abs(cur_x.val - prev_x.val) #Change in x
    iters += 1 #iteration count
    print("Iteration",iters,"\nX value is", cur_x.val) #Print iterations
    
print("The local minimum occurs at", cur_x.val)
# Out:
# Iteration 1
# X value is [2.84]
# Iteration 2
# X value is [2.6832]
# Iteration 3
# X value is [2.529536]
# Iteration 4
# X value is [2.37894528]
# Iteration 5
# X value is [2.23136637]
# Iteration 6
# X value is [2.08673905]
# Iteration 7
# X value is [1.94500427]
# Iteration 8
# X value is [1.80610418]
# Iteration 9
# X value is [1.6699821]
# Iteration 10
# X value is [1.53658246]
# Iteration 11
# X value is [1.40585081]
# Iteration 12
# X value is [1.27773379]
# Iteration 13
# X value is [1.15217911]
# Iteration 14
# X value is [1.02913553]
# Iteration 15
# X value is [0.90855282]
# Iteration 16
# X value is [0.79038176]
# Iteration 17
# X value is [0.67457413]
# Iteration 18
# X value is [0.56108265]
# Iteration 19
# X value is [0.44986099]
# Iteration 20
# X value is [0.34086377]
# Iteration 21
# X value is [0.2340465]
# Iteration 22
# X value is [0.12936557]
# Iteration 23
# X value is [0.02677826]
# Iteration 24
# X value is [-0.07375731]
# Iteration 25
# X value is [-0.17228216]
# Iteration 26
# X value is [-0.26883652]
# Iteration 27
# X value is [-0.36345979]
# Iteration 28
# X value is [-0.45619059]
# Iteration 29
# X value is [-0.54706678]
# Iteration 30
# X value is [-0.63612544]
# Iteration 31
# X value is [-0.72340294]
# Iteration 32
# X value is [-0.80893488]
# Iteration 33
# X value is [-0.89275618]
# Iteration 34
# X value is [-0.97490106]
# Iteration 35
# X value is [-1.05540304]
# Iteration 36
# X value is [-1.13429497]
# Iteration 37
# X value is [-1.21160907]
# Iteration 38
# X value is [-1.28737689]
# Iteration 39
# X value is [-1.36162936]
# Iteration 40
# X value is [-1.43439677]
# Iteration 41
# X value is [-1.50570883]
# Iteration 42
# X value is [-1.57559466]
# Iteration 43
# X value is [-1.64408276]
# Iteration 44
# X value is [-1.71120111]
# Iteration 45
# X value is [-1.77697709]
# Iteration 46
# X value is [-1.84143754]
# Iteration 47
# X value is [-1.90460879]
# Iteration 48
# X value is [-1.96651662]
# Iteration 49
# X value is [-2.02718629]
# Iteration 50
# X value is [-2.08664256]
# Iteration 51
# X value is [-2.14490971]
# Iteration 52
# X value is [-2.20201151]
# Iteration 53
# X value is [-2.25797128]
# Iteration 54
# X value is [-2.31281186]
# Iteration 55
# X value is [-2.36655562]
# Iteration 56
# X value is [-2.41922451]
# Iteration 57
# X value is [-2.47084002]
# Iteration 58
# X value is [-2.52142322]
# Iteration 59
# X value is [-2.57099475]
# Iteration 60
# X value is [-2.61957486]
# Iteration 61
# X value is [-2.66718336]
# Iteration 62
# X value is [-2.71383969]
# Iteration 63
# X value is [-2.7595629]
# Iteration 64
# X value is [-2.80437164]
# Iteration 65
# X value is [-2.84828421]
# Iteration 66
# X value is [-2.89131853]
# Iteration 67
# X value is [-2.93349215]
# Iteration 68
# X value is [-2.97482231]
# Iteration 69
# X value is [-3.01532587]
# Iteration 70
# X value is [-3.05501935]
# Iteration 71
# X value is [-3.09391896]
# Iteration 72
# X value is [-3.13204058]
# Iteration 73
# X value is [-3.16939977]
# Iteration 74
# X value is [-3.20601177]
# Iteration 75
# X value is [-3.24189154]
# Iteration 76
# X value is [-3.27705371]
# Iteration 77
# X value is [-3.31151263]
# Iteration 78
# X value is [-3.34528238]
# Iteration 79
# X value is [-3.37837673]
# Iteration 80
# X value is [-3.4108092]
# Iteration 81
# X value is [-3.44259302]
# Iteration 82
# X value is [-3.47374116]
# Iteration 83
# X value is [-3.50426633]
# Iteration 84
# X value is [-3.53418101]
# Iteration 85
# X value is [-3.56349739]
# Iteration 86
# X value is [-3.59222744]
# Iteration 87
# X value is [-3.62038289]
# Iteration 88
# X value is [-3.64797523]
# Iteration 89
# X value is [-3.67501573]
# Iteration 90
# X value is [-3.70151541]
# Iteration 91
# X value is [-3.7274851]
# Iteration 92
# X value is [-3.7529354]
# Iteration 93
# X value is [-3.77787669]
# Iteration 94
# X value is [-3.80231916]
# Iteration 95
# X value is [-3.82627278]
# Iteration 96
# X value is [-3.84974732]
# Iteration 97
# X value is [-3.87275237]
# Iteration 98
# X value is [-3.89529733]
# Iteration 99
# X value is [-3.91739138]
# Iteration 100
# X value is [-3.93904355]
# Iteration 101
# X value is [-3.96026268]
# Iteration 102
# X value is [-3.98105743]
# Iteration 103
# X value is [-4.00143628]
# Iteration 104
# X value is [-4.02140755]
# Iteration 105
# X value is [-4.0409794]
# Iteration 106
# X value is [-4.06015981]
# Iteration 107
# X value is [-4.07895662]
# Iteration 108
# X value is [-4.09737749]
# Iteration 109
# X value is [-4.11542994]
# Iteration 110
# X value is [-4.13312134]
# Iteration 111
# X value is [-4.15045891]
# Iteration 112
# X value is [-4.16744973]
# Iteration 113
# X value is [-4.18410074]
# Iteration 114
# X value is [-4.20041872]
# Iteration 115
# X value is [-4.21641035]
# Iteration 116
# X value is [-4.23208214]
# Iteration 117
# X value is [-4.2474405]
# Iteration 118
# X value is [-4.26249169]
# Iteration 119
# X value is [-4.27724186]
# Iteration 120
# X value is [-4.29169702]
# Iteration 121
# X value is [-4.30586308]
# Iteration 122
# X value is [-4.31974582]
# Iteration 123
# X value is [-4.3333509]
# Iteration 124
# X value is [-4.34668388]
# Iteration 125
# X value is [-4.3597502]
# Iteration 126
# X value is [-4.3725552]
# Iteration 127
# X value is [-4.3851041]
# Iteration 128
# X value is [-4.39740201]
# Iteration 129
# X value is [-4.40945397]
# Iteration 130
# X value is [-4.42126489]
# Iteration 131
# X value is [-4.4328396]
# Iteration 132
# X value is [-4.4441828]
# Iteration 133
# X value is [-4.45529915]
# Iteration 134
# X value is [-4.46619317]
# Iteration 135
# X value is [-4.4768693]
# Iteration 136
# X value is [-4.48733192]
# Iteration 137
# X value is [-4.49758528]
# Iteration 138
# X value is [-4.50763357]
# Iteration 139
# X value is [-4.5174809]
# Iteration 140
# X value is [-4.52713128]
# Iteration 141
# X value is [-4.53658866]
# Iteration 142
# X value is [-4.54585688]
# Iteration 143
# X value is [-4.55493975]
# Iteration 144
# X value is [-4.56384095]
# Iteration 145
# X value is [-4.57256413]
# Iteration 146
# X value is [-4.58111285]
# Iteration 147
# X value is [-4.58949059]
# Iteration 148
# X value is [-4.59770078]
# Iteration 149
# X value is [-4.60574677]
# Iteration 150
# X value is [-4.61363183]
# Iteration 151
# X value is [-4.62135919]
# Iteration 152
# X value is [-4.62893201]
# Iteration 153
# X value is [-4.63635337]
# Iteration 154
# X value is [-4.6436263]
# Iteration 155
# X value is [-4.65075378]
# Iteration 156
# X value is [-4.6577387]
# Iteration 157
# X value is [-4.66458393]
# Iteration 158
# X value is [-4.67129225]
# Iteration 159
# X value is [-4.6778664]
# Iteration 160
# X value is [-4.68430907]
# Iteration 161
# X value is [-4.69062289]
# Iteration 162
# X value is [-4.69681044]
# Iteration 163
# X value is [-4.70287423]
# Iteration 164
# X value is [-4.70881674]
# Iteration 165
# X value is [-4.71464041]
# Iteration 166
# X value is [-4.7203476]
# Iteration 167
# X value is [-4.72594065]
# Iteration 168
# X value is [-4.73142183]
# Iteration 169
# X value is [-4.7367934]
# Iteration 170
# X value is [-4.74205753]
# Iteration 171
# X value is [-4.74721638]
# Iteration 172
# X value is [-4.75227205]
# Iteration 173
# X value is [-4.75722661]
# Iteration 174
# X value is [-4.76208208]
# Iteration 175
# X value is [-4.76684044]
# Iteration 176
# X value is [-4.77150363]
# Iteration 177
# X value is [-4.77607356]
# Iteration 178
# X value is [-4.78055208]
# Iteration 179
# X value is [-4.78494104]
# Iteration 180
# X value is [-4.78924222]
# Iteration 181
# X value is [-4.79345738]
# Iteration 182
# X value is [-4.79758823]
# Iteration 183
# X value is [-4.80163647]
# Iteration 184
# X value is [-4.80560374]
# Iteration 185
# X value is [-4.80949166]
# Iteration 186
# X value is [-4.81330183]
# Iteration 187
# X value is [-4.81703579]
# Iteration 188
# X value is [-4.82069508]
# Iteration 189
# X value is [-4.82428117]
# Iteration 190
# X value is [-4.82779555]
# Iteration 191
# X value is [-4.83123964]
# Iteration 192
# X value is [-4.83461485]
# Iteration 193
# X value is [-4.83792255]
# Iteration 194
# X value is [-4.8411641]
# Iteration 195
# X value is [-4.84434082]
# Iteration 196
# X value is [-4.847454]
# Iteration 197
# X value is [-4.85050492]
# Iteration 198
# X value is [-4.85349482]
# Iteration 199
# X value is [-4.85642493]
# Iteration 200
# X value is [-4.85929643]
# Iteration 201
# X value is [-4.8621105]
# Iteration 202
# X value is [-4.86486829]
# Iteration 203
# X value is [-4.86757092]
# Iteration 204
# X value is [-4.8702195]
# Iteration 205
# X value is [-4.87281511]
# Iteration 206
# X value is [-4.87535881]
# Iteration 207
# X value is [-4.87785164]
# Iteration 208
# X value is [-4.8802946]
# Iteration 209
# X value is [-4.88268871]
# Iteration 210
# X value is [-4.88503494]
# Iteration 211
# X value is [-4.88733424]
# Iteration 212
# X value is [-4.88958755]
# Iteration 213
# X value is [-4.8917958]
# Iteration 214
# X value is [-4.89395989]
# Iteration 215
# X value is [-4.89608069]
# Iteration 216
# X value is [-4.89815907]
# Iteration 217
# X value is [-4.90019589]
# Iteration 218
# X value is [-4.90219198]
# Iteration 219
# X value is [-4.90414814]
# Iteration 220
# X value is [-4.90606517]
# Iteration 221
# X value is [-4.90794387]
# Iteration 222
# X value is [-4.90978499]
# Iteration 223
# X value is [-4.91158929]
# Iteration 224
# X value is [-4.91335751]
# Iteration 225
# X value is [-4.91509036]
# Iteration 226
# X value is [-4.91678855]
# Iteration 227
# X value is [-4.91845278]
# Iteration 228
# X value is [-4.92008372]
# Iteration 229
# X value is [-4.92168205]
# Iteration 230
# X value is [-4.92324841]
# Iteration 231
# X value is [-4.92478344]
# Iteration 232
# X value is [-4.92628777]
# Iteration 233
# X value is [-4.92776201]
# Iteration 234
# X value is [-4.92920677]
# Iteration 235
# X value is [-4.93062264]
# Iteration 236
# X value is [-4.93201019]
# Iteration 237
# X value is [-4.93336998]
# Iteration 238
# X value is [-4.93470258]
# Iteration 239
# X value is [-4.93600853]
# Iteration 240
# X value is [-4.93728836]
# Iteration 241
# X value is [-4.93854259]
# Iteration 242
# X value is [-4.93977174]
# Iteration 243
# X value is [-4.94097631]
# Iteration 244
# X value is [-4.94215678]
# Iteration 245
# X value is [-4.94331365]
# Iteration 246
# X value is [-4.94444737]
# Iteration 247
# X value is [-4.94555842]
# Iteration 248
# X value is [-4.94664726]
# Iteration 249
# X value is [-4.94771431]
# Iteration 250
# X value is [-4.94876002]
# Iteration 251
# X value is [-4.94978482]
# Iteration 252
# X value is [-4.95078913]
# Iteration 253
# X value is [-4.95177335]
# Iteration 254
# X value is [-4.95273788]
# Iteration 255
# X value is [-4.95368312]
# Iteration 256
# X value is [-4.95460946]
# Iteration 257
# X value is [-4.95551727]
# Iteration 258
# X value is [-4.95640692]
# Iteration 259
# X value is [-4.95727879]
# Iteration 260
# X value is [-4.95813321]
# Iteration 261
# X value is [-4.95897055]
# Iteration 262
# X value is [-4.95979113]
# Iteration 263
# X value is [-4.96059531]
# Iteration 264
# X value is [-4.96138341]
# Iteration 265
# X value is [-4.96215574]
# Iteration 266
# X value is [-4.96291262]
# Iteration 267
# X value is [-4.96365437]
# Iteration 268
# X value is [-4.96438128]
# Iteration 269
# X value is [-4.96509366]
# Iteration 270
# X value is [-4.96579178]
# Iteration 271
# X value is [-4.96647595]
# Iteration 272
# X value is [-4.96714643]
# Iteration 273
# X value is [-4.9678035]
# Iteration 274
# X value is [-4.96844743]
# Iteration 275
# X value is [-4.96907848]
# Iteration 276
# X value is [-4.96969691]
# Iteration 277
# X value is [-4.97030297]
# Iteration 278
# X value is [-4.97089691]
# Iteration 279
# X value is [-4.97147898]
# Iteration 280
# X value is [-4.9720494]
# Iteration 281
# X value is [-4.97260841]
# Iteration 282
# X value is [-4.97315624]
# Iteration 283
# X value is [-4.97369312]
# Iteration 284
# X value is [-4.97421925]
# Iteration 285
# X value is [-4.97473487]
# Iteration 286
# X value is [-4.97524017]
# Iteration 287
# X value is [-4.97573537]
# Iteration 288
# X value is [-4.97622066]
# Iteration 289
# X value is [-4.97669625]
# Iteration 290
# X value is [-4.97716232]
# Iteration 291
# X value is [-4.97761908]
# Iteration 292
# X value is [-4.97806669]
# Iteration 293
# X value is [-4.97850536]
# Iteration 294
# X value is [-4.97893525]
# Iteration 295
# X value is [-4.97935655]
# Iteration 296
# X value is [-4.97976942]
# Iteration 297
# X value is [-4.98017403]
# Iteration 298
# X value is [-4.98057055]
# Iteration 299
# X value is [-4.98095914]
# Iteration 300
# X value is [-4.98133995]
# Iteration 301
# X value is [-4.98171316]
# Iteration 302
# X value is [-4.98207889]
# Iteration 303
# X value is [-4.98243731]
# Iteration 304
# X value is [-4.98278857]
# Iteration 305
# X value is [-4.9831328]
# Iteration 306
# X value is [-4.98347014]
# Iteration 307
# X value is [-4.98380074]
# Iteration 308
# X value is [-4.98412472]
# Iteration 309
# X value is [-4.98444223]
# Iteration 310
# X value is [-4.98475338]
# Iteration 311
# X value is [-4.98505832]
# Iteration 312
# X value is [-4.98535715]
# Iteration 313
# X value is [-4.98565001]
# Iteration 314
# X value is [-4.98593701]
# Iteration 315
# X value is [-4.98621827]
# Iteration 316
# X value is [-4.9864939]
# Iteration 317
# X value is [-4.98676402]
# Iteration 318
# X value is [-4.98702874]
# Iteration 319
# X value is [-4.98728817]
# Iteration 320
# X value is [-4.9875424]
# Iteration 321
# X value is [-4.98779156]
# Iteration 322
# X value is [-4.98803573]
# Iteration 323
# X value is [-4.98827501]
# Iteration 324
# X value is [-4.98850951]
# Iteration 325
# X value is [-4.98873932]
# Iteration 326
# X value is [-4.98896453]
# Iteration 327
# X value is [-4.98918524]
# Iteration 328
# X value is [-4.98940154]
# Iteration 329
# X value is [-4.98961351]
# Iteration 330
# X value is [-4.98982124]
# Iteration 331
# X value is [-4.99002481]
# Iteration 332
# X value is [-4.99022432]
# Iteration 333
# X value is [-4.99041983]
# Iteration 334
# X value is [-4.99061143]
# Iteration 335
# X value is [-4.99079921]
# Iteration 336
# X value is [-4.99098322]
# Iteration 337
# X value is [-4.99116356]
# Iteration 338
# X value is [-4.99134029]
# Iteration 339
# X value is [-4.99151348]
# Iteration 340
# X value is [-4.99168321]
# Iteration 341
# X value is [-4.99184955]
# Iteration 342
# X value is [-4.99201256]
# Iteration 343
# X value is [-4.9921723]
# Iteration 344
# X value is [-4.99232886]
# Iteration 345
# X value is [-4.99248228]
# Iteration 346
# X value is [-4.99263264]
# Iteration 347
# X value is [-4.99277998]
# Iteration 348
# X value is [-4.99292438]
# Iteration 349
# X value is [-4.9930659]
# Iteration 350
# X value is [-4.99320458]
# Iteration 351
# X value is [-4.99334049]
# Iteration 352
# X value is [-4.99347368]
# Iteration 353
# X value is [-4.9936042]
# Iteration 354
# X value is [-4.99373212]
# Iteration 355
# X value is [-4.99385748]
# Iteration 356
# X value is [-4.99398033]
# Iteration 357
# X value is [-4.99410072]
# Iteration 358
# X value is [-4.99421871]
# Iteration 359
# X value is [-4.99433433]
# Iteration 360
# X value is [-4.99444764]
# Iteration 361
# X value is [-4.99455869]
# Iteration 362
# X value is [-4.99466752]
# Iteration 363
# X value is [-4.99477417]
# Iteration 364
# X value is [-4.99487868]
# Iteration 365
# X value is [-4.99498111]
# Iteration 366
# X value is [-4.99508149]
# Iteration 367
# X value is [-4.99517986]
# Iteration 368
# X value is [-4.99527626]
# Iteration 369
# X value is [-4.99537074]
# Iteration 370
# X value is [-4.99546332]
# Iteration 371
# X value is [-4.99555406]
# Iteration 372
# X value is [-4.99564297]
# Iteration 373
# X value is [-4.99573011]
# Iteration 374
# X value is [-4.99581551]
# Iteration 375
# X value is [-4.9958992]
# Iteration 376
# X value is [-4.99598122]
# Iteration 377
# X value is [-4.99606159]
# Iteration 378
# X value is [-4.99614036]
# Iteration 379
# X value is [-4.99621755]
# Iteration 380
# X value is [-4.9962932]
# Iteration 381
# X value is [-4.99636734]
# Iteration 382
# X value is [-4.99643999]
# Iteration 383
# X value is [-4.99651119]
# Iteration 384
# X value is [-4.99658097]
# Iteration 385
# X value is [-4.99664935]
# Iteration 386
# X value is [-4.99671636]
# Iteration 387
# X value is [-4.99678204]
# Iteration 388
# X value is [-4.99684639]
# Iteration 389
# X value is [-4.99690947]
# Iteration 390
# X value is [-4.99697128]
# Iteration 391
# X value is [-4.99703185]
# Iteration 392
# X value is [-4.99709121]
# Iteration 393
# X value is [-4.99714939]
# Iteration 394
# X value is [-4.9972064]
# Iteration 395
# X value is [-4.99726227]
# Iteration 396
# X value is [-4.99731703]
# Iteration 397
# X value is [-4.99737069]
# Iteration 398
# X value is [-4.99742327]
# Iteration 399
# X value is [-4.99747481]
# Iteration 400
# X value is [-4.99752531]
# Iteration 401
# X value is [-4.99757481]
# Iteration 402
# X value is [-4.99762331]
# Iteration 403
# X value is [-4.99767084]
# Iteration 404
# X value is [-4.99771743]
# Iteration 405
# X value is [-4.99776308]
# Iteration 406
# X value is [-4.99780782]
# Iteration 407
# X value is [-4.99785166]
# Iteration 408
# X value is [-4.99789463]
# Iteration 409
# X value is [-4.99793674]
# Iteration 410
# X value is [-4.997978]
# Iteration 411
# X value is [-4.99801844]
# Iteration 412
# X value is [-4.99805807]
# Iteration 413
# X value is [-4.99809691]
# Iteration 414
# X value is [-4.99813497]
# Iteration 415
# X value is [-4.99817227]
# Iteration 416
# X value is [-4.99820883]
# Iteration 417
# X value is [-4.99824465]
# Iteration 418
# X value is [-4.99827976]
# Iteration 419
# X value is [-4.99831416]
# Iteration 420
# X value is [-4.99834788]
# Iteration 421
# X value is [-4.99838092]
# Iteration 422
# X value is [-4.9984133]
# Iteration 423
# X value is [-4.99844504]
# Iteration 424
# X value is [-4.99847614]
# Iteration 425
# X value is [-4.99850661]
# Iteration 426
# X value is [-4.99853648]
# Iteration 427
# X value is [-4.99856575]
# Iteration 428
# X value is [-4.99859444]
# Iteration 429
# X value is [-4.99862255]
# Iteration 430
# X value is [-4.9986501]
# Iteration 431
# X value is [-4.9986771]
# Iteration 432
# X value is [-4.99870355]
# Iteration 433
# X value is [-4.99872948]
# Iteration 434
# X value is [-4.99875489]
# Iteration 435
# X value is [-4.99877979]
# Iteration 436
# X value is [-4.9988042]
# Iteration 437
# X value is [-4.99882811]
# Iteration 438
# X value is [-4.99885155]
# Iteration 439
# X value is [-4.99887452]
# Iteration 440
# X value is [-4.99889703]
# Iteration 441
# X value is [-4.99891909]
# Iteration 442
# X value is [-4.99894071]
# Iteration 443
# X value is [-4.99896189]
# Iteration 444
# X value is [-4.99898266]
# Iteration 445
# X value is [-4.999003]
# Iteration 446
# X value is [-4.99902294]
# Iteration 447
# X value is [-4.99904248]
# Iteration 448
# X value is [-4.99906163]
# Iteration 449
# X value is [-4.9990804]
# Iteration 450
# X value is [-4.99909879]
# Iteration 451
# X value is [-4.99911682]
# Iteration 452
# X value is [-4.99913448]
# Iteration 453
# X value is [-4.99915179]
# Iteration 454
# X value is [-4.99916876]
# Iteration 455
# X value is [-4.99918538]
# Iteration 456
# X value is [-4.99920167]
# Iteration 457
# X value is [-4.99921764]
# Iteration 458
# X value is [-4.99923329]
# Iteration 459
# X value is [-4.99924862]
# Iteration 460
# X value is [-4.99926365]
# Iteration 461
# X value is [-4.99927838]
# Iteration 462
# X value is [-4.99929281]
# Iteration 463
# X value is [-4.99930695]
# Iteration 464
# X value is [-4.99932081]
# Iteration 465
# X value is [-4.9993344]
# Iteration 466
# X value is [-4.99934771]
# Iteration 467
# X value is [-4.99936076]
# Iteration 468
# X value is [-4.99937354]
# Iteration 469
# X value is [-4.99938607]
# Iteration 470
# X value is [-4.99939835]
# Iteration 471
# X value is [-4.99941038]
# Iteration 472
# X value is [-4.99942217]
# Iteration 473
# X value is [-4.99943373]
# Iteration 474
# X value is [-4.99944506]
# Iteration 475
# X value is [-4.99945615]
# Iteration 476
# X value is [-4.99946703]
# Iteration 477
# X value is [-4.99947769]
# Iteration 478
# X value is [-4.99948814]
# Iteration 479
# X value is [-4.99949837]
# Iteration 480
# X value is [-4.99950841]
# Iteration 481
# X value is [-4.99951824]
# Iteration 482
# X value is [-4.99952787]
# Iteration 483
# X value is [-4.99953732]
# Iteration 484
# X value is [-4.99954657]
# Iteration 485
# X value is [-4.99955564]
# Iteration 486
# X value is [-4.99956453]
# Iteration 487
# X value is [-4.99957323]
# Iteration 488
# X value is [-4.99958177]
# Iteration 489
# X value is [-4.99959013]
# Iteration 490
# X value is [-4.99959833]
# Iteration 491
# X value is [-4.99960637]
# Iteration 492
# X value is [-4.99961424]
# Iteration 493
# X value is [-4.99962195]
# Iteration 494
# X value is [-4.99962951]
# Iteration 495
# X value is [-4.99963692]
# Iteration 496
# X value is [-4.99964419]
# Iteration 497
# X value is [-4.9996513]
# Iteration 498
# X value is [-4.99965828]
# Iteration 499
# X value is [-4.99966511]
# Iteration 500
# X value is [-4.99967181]
# Iteration 501
# X value is [-4.99967837]
# Iteration 502
# X value is [-4.9996848]
# Iteration 503
# X value is [-4.99969111]
# Iteration 504
# X value is [-4.99969729]
# Iteration 505
# X value is [-4.99970334]
# Iteration 506
# X value is [-4.99970927]
# Iteration 507
# X value is [-4.99971509]
# Iteration 508
# X value is [-4.99972079]
# Iteration 509
# X value is [-4.99972637]
# Iteration 510
# X value is [-4.99973184]
# Iteration 511
# X value is [-4.99973721]
# Iteration 512
# X value is [-4.99974246]
# Iteration 513
# X value is [-4.99974761]
# Iteration 514
# X value is [-4.99975266]
# Iteration 515
# X value is [-4.99975761]
# Iteration 516
# X value is [-4.99976246]
# Iteration 517
# X value is [-4.99976721]
# Iteration 518
# X value is [-4.99977186]
# Iteration 519
# X value is [-4.99977642]
# Iteration 520
# X value is [-4.9997809]
# Iteration 521
# X value is [-4.99978528]
# Iteration 522
# X value is [-4.99978957]
# Iteration 523
# X value is [-4.99979378]
# Iteration 524
# X value is [-4.99979791]
# Iteration 525
# X value is [-4.99980195]
# Iteration 526
# X value is [-4.99980591]
# Iteration 527
# X value is [-4.99980979]
# Iteration 528
# X value is [-4.99981359]
# Iteration 529
# X value is [-4.99981732]
# Iteration 530
# X value is [-4.99982098]
# Iteration 531
# X value is [-4.99982456]
# Iteration 532
# X value is [-4.99982807]
# Iteration 533
# X value is [-4.9998315]
# Iteration 534
# X value is [-4.99983487]
# Iteration 535
# X value is [-4.99983818]
# Iteration 536
# X value is [-4.99984141]
# Iteration 537
# X value is [-4.99984459]
# Iteration 538
# X value is [-4.99984769]
# Iteration 539
# X value is [-4.99985074]
# Iteration 540
# X value is [-4.99985372]
# Iteration 541
# X value is [-4.99985665]
# Iteration 542
# X value is [-4.99985952]
# Iteration 543
# X value is [-4.99986233]
# Iteration 544
# X value is [-4.99986508]
# Iteration 545
# X value is [-4.99986778]
# Iteration 546
# X value is [-4.99987042]
# Iteration 547
# X value is [-4.99987301]
# Iteration 548
# X value is [-4.99987555]
# Iteration 549
# X value is [-4.99987804]
# Iteration 550
# X value is [-4.99988048]
# Iteration 551
# X value is [-4.99988287]
# Iteration 552
# X value is [-4.99988522]
# Iteration 553
# X value is [-4.99988751]
# Iteration 554
# X value is [-4.99988976]
# Iteration 555
# X value is [-4.99989197]
# Iteration 556
# X value is [-4.99989413]
# Iteration 557
# X value is [-4.99989624]
# Iteration 558
# X value is [-4.99989832]
# Iteration 559
# X value is [-4.99990035]
# Iteration 560
# X value is [-4.99990235]
# Iteration 561
# X value is [-4.9999043]
# Iteration 562
# X value is [-4.99990621]
# Iteration 563
# X value is [-4.99990809]
# Iteration 564
# X value is [-4.99990993]
# Iteration 565
# X value is [-4.99991173]
# Iteration 566
# X value is [-4.99991349]
# Iteration 567
# X value is [-4.99991522]
# Iteration 568
# X value is [-4.99991692]
# Iteration 569
# X value is [-4.99991858]
# Iteration 570
# X value is [-4.99992021]
# Iteration 571
# X value is [-4.9999218]
# Iteration 572
# X value is [-4.99992337]
# Iteration 573
# X value is [-4.9999249]
# Iteration 574
# X value is [-4.9999264]
# Iteration 575
# X value is [-4.99992788]
# Iteration 576
# X value is [-4.99992932]
# Iteration 577
# X value is [-4.99993073]
# Iteration 578
# X value is [-4.99993212]
# Iteration 579
# X value is [-4.99993347]
# Iteration 580
# X value is [-4.99993481]
# Iteration 581
# X value is [-4.99993611]
# Iteration 582
# X value is [-4.99993739]
# Iteration 583
# X value is [-4.99993864]
# Iteration 584
# X value is [-4.99993987]
# Iteration 585
# X value is [-4.99994107]
# Iteration 586
# X value is [-4.99994225]
# Iteration 587
# X value is [-4.9999434]
# Iteration 588
# X value is [-4.99994453]
# Iteration 589
# X value is [-4.99994564]
# Iteration 590
# X value is [-4.99994673]
# Iteration 591
# X value is [-4.9999478]
# Iteration 592
# X value is [-4.99994884]
# Iteration 593
# X value is [-4.99994986]
# Iteration 594
# X value is [-4.99995087]
# Iteration 595
# X value is [-4.99995185]
# The local minimum occurs at [-4.99995185]

# %%
def gradient_descent(variables, f, cur_x, rate, precision, previous_step_size, max_iters):
    if isinstance(f, str):

    #If just one string, convert to list
        if isinstance(variables, str):

            variables = [variables]

        #Convert to numpy arrays
        variables = np.array(variables)
        cur_x = np.array(cur_x)

        iters = 0
        while previous_step_size > precision and iters < max_iters:
            for index, variable in enumerate(variables):

                #Store to variable name
                name = variable

                #Save as forwardAD object
                exec(name + " = forwardAD(np.array(cur_x), numvar = len(variables), idx = index)")

            #Stores full function as a forwardAD object
            AD_function = eval(f)
            
            prev_x = cur_x #Store current x value in prev_x
            cur_x = cur_x - rate * AD_function.der #Grad descent
            previous_step_size = abs(cur_x - prev_x) #Change in x
            iters += 1 #iteration count
            print("Iteration",iters,"\nX value is", cur_x) #Print iterations

    print("The local minimum occurs at", cur_x)

# %%
variables = "x"
f = "(x+5)**2"
cur_x = [3]
rate = 0.01
precision = 0.000001
previous_step_size = 1
max_iters = 10000
iters = 0
gradient_descent(variables, f, cur_x, rate, precision, previous_step_size, max_iters)
# Out:
# Iteration 1
# X value is [2.84]
# Iteration 2
# X value is [2.6832]
# Iteration 3
# X value is [2.529536]
# Iteration 4
# X value is [2.37894528]
# Iteration 5
# X value is [2.23136637]
# Iteration 6
# X value is [2.08673905]
# Iteration 7
# X value is [1.94500427]
# Iteration 8
# X value is [1.80610418]
# Iteration 9
# X value is [1.6699821]
# Iteration 10
# X value is [1.53658246]
# Iteration 11
# X value is [1.40585081]
# Iteration 12
# X value is [1.27773379]
# Iteration 13
# X value is [1.15217911]
# Iteration 14
# X value is [1.02913553]
# Iteration 15
# X value is [0.90855282]
# Iteration 16
# X value is [0.79038176]
# Iteration 17
# X value is [0.67457413]
# Iteration 18
# X value is [0.56108265]
# Iteration 19
# X value is [0.44986099]
# Iteration 20
# X value is [0.34086377]
# Iteration 21
# X value is [0.2340465]
# Iteration 22
# X value is [0.12936557]
# Iteration 23
# X value is [0.02677826]
# Iteration 24
# X value is [-0.07375731]
# Iteration 25
# X value is [-0.17228216]
# Iteration 26
# X value is [-0.26883652]
# Iteration 27
# X value is [-0.36345979]
# Iteration 28
# X value is [-0.45619059]
# Iteration 29
# X value is [-0.54706678]
# Iteration 30
# X value is [-0.63612544]
# Iteration 31
# X value is [-0.72340294]
# Iteration 32
# X value is [-0.80893488]
# Iteration 33
# X value is [-0.89275618]
# Iteration 34
# X value is [-0.97490106]
# Iteration 35
# X value is [-1.05540304]
# Iteration 36
# X value is [-1.13429497]
# Iteration 37
# X value is [-1.21160907]
# Iteration 38
# X value is [-1.28737689]
# Iteration 39
# X value is [-1.36162936]
# Iteration 40
# X value is [-1.43439677]
# Iteration 41
# X value is [-1.50570883]
# Iteration 42
# X value is [-1.57559466]
# Iteration 43
# X value is [-1.64408276]
# Iteration 44
# X value is [-1.71120111]
# Iteration 45
# X value is [-1.77697709]
# Iteration 46
# X value is [-1.84143754]
# Iteration 47
# X value is [-1.90460879]
# Iteration 48
# X value is [-1.96651662]
# Iteration 49
# X value is [-2.02718629]
# Iteration 50
# X value is [-2.08664256]
# Iteration 51
# X value is [-2.14490971]
# Iteration 52
# X value is [-2.20201151]
# Iteration 53
# X value is [-2.25797128]
# Iteration 54
# X value is [-2.31281186]
# Iteration 55
# X value is [-2.36655562]
# Iteration 56
# X value is [-2.41922451]
# Iteration 57
# X value is [-2.47084002]
# Iteration 58
# X value is [-2.52142322]
# Iteration 59
# X value is [-2.57099475]
# Iteration 60
# X value is [-2.61957486]
# Iteration 61
# X value is [-2.66718336]
# Iteration 62
# X value is [-2.71383969]
# Iteration 63
# X value is [-2.7595629]
# Iteration 64
# X value is [-2.80437164]
# Iteration 65
# X value is [-2.84828421]
# Iteration 66
# X value is [-2.89131853]
# Iteration 67
# X value is [-2.93349215]
# Iteration 68
# X value is [-2.97482231]
# Iteration 69
# X value is [-3.01532587]
# Iteration 70
# X value is [-3.05501935]
# Iteration 71
# X value is [-3.09391896]
# Iteration 72
# X value is [-3.13204058]
# Iteration 73
# X value is [-3.16939977]
# Iteration 74
# X value is [-3.20601177]
# Iteration 75
# X value is [-3.24189154]
# Iteration 76
# X value is [-3.27705371]
# Iteration 77
# X value is [-3.31151263]
# Iteration 78
# X value is [-3.34528238]
# Iteration 79
# X value is [-3.37837673]
# Iteration 80
# X value is [-3.4108092]
# Iteration 81
# X value is [-3.44259302]
# Iteration 82
# X value is [-3.47374116]
# Iteration 83
# X value is [-3.50426633]
# Iteration 84
# X value is [-3.53418101]
# Iteration 85
# X value is [-3.56349739]
# Iteration 86
# X value is [-3.59222744]
# Iteration 87
# X value is [-3.62038289]
# Iteration 88
# X value is [-3.64797523]
# Iteration 89
# X value is [-3.67501573]
# Iteration 90
# X value is [-3.70151541]
# Iteration 91
# X value is [-3.7274851]
# Iteration 92
# X value is [-3.7529354]
# Iteration 93
# X value is [-3.77787669]
# Iteration 94
# X value is [-3.80231916]
# Iteration 95
# X value is [-3.82627278]
# Iteration 96
# X value is [-3.84974732]
# Iteration 97
# X value is [-3.87275237]
# Iteration 98
# X value is [-3.89529733]
# Iteration 99
# X value is [-3.91739138]
# Iteration 100
# X value is [-3.93904355]
# Iteration 101
# X value is [-3.96026268]
# Iteration 102
# X value is [-3.98105743]
# Iteration 103
# X value is [-4.00143628]
# Iteration 104
# X value is [-4.02140755]
# Iteration 105
# X value is [-4.0409794]
# Iteration 106
# X value is [-4.06015981]
# Iteration 107
# X value is [-4.07895662]
# Iteration 108
# X value is [-4.09737749]
# Iteration 109
# X value is [-4.11542994]
# Iteration 110
# X value is [-4.13312134]
# Iteration 111
# X value is [-4.15045891]
# Iteration 112
# X value is [-4.16744973]
# Iteration 113
# X value is [-4.18410074]
# Iteration 114
# X value is [-4.20041872]
# Iteration 115
# X value is [-4.21641035]
# Iteration 116
# X value is [-4.23208214]
# Iteration 117
# X value is [-4.2474405]
# Iteration 118
# X value is [-4.26249169]
# Iteration 119
# X value is [-4.27724186]
# Iteration 120
# X value is [-4.29169702]
# Iteration 121
# X value is [-4.30586308]
# Iteration 122
# X value is [-4.31974582]
# Iteration 123
# X value is [-4.3333509]
# Iteration 124
# X value is [-4.34668388]
# Iteration 125
# X value is [-4.3597502]
# Iteration 126
# X value is [-4.3725552]
# Iteration 127
# X value is [-4.3851041]
# Iteration 128
# X value is [-4.39740201]
# Iteration 129
# X value is [-4.40945397]
# Iteration 130
# X value is [-4.42126489]
# Iteration 131
# X value is [-4.4328396]
# Iteration 132
# X value is [-4.4441828]
# Iteration 133
# X value is [-4.45529915]
# Iteration 134
# X value is [-4.46619317]
# Iteration 135
# X value is [-4.4768693]
# Iteration 136
# X value is [-4.48733192]
# Iteration 137
# X value is [-4.49758528]
# Iteration 138
# X value is [-4.50763357]
# Iteration 139
# X value is [-4.5174809]
# Iteration 140
# X value is [-4.52713128]
# Iteration 141
# X value is [-4.53658866]
# Iteration 142
# X value is [-4.54585688]
# Iteration 143
# X value is [-4.55493975]
# Iteration 144
# X value is [-4.56384095]
# Iteration 145
# X value is [-4.57256413]
# Iteration 146
# X value is [-4.58111285]
# Iteration 147
# X value is [-4.58949059]
# Iteration 148
# X value is [-4.59770078]
# Iteration 149
# X value is [-4.60574677]
# Iteration 150
# X value is [-4.61363183]
# Iteration 151
# X value is [-4.62135919]
# Iteration 152
# X value is [-4.62893201]
# Iteration 153
# X value is [-4.63635337]
# Iteration 154
# X value is [-4.6436263]
# Iteration 155
# X value is [-4.65075378]
# Iteration 156
# X value is [-4.6577387]
# Iteration 157
# X value is [-4.66458393]
# Iteration 158
# X value is [-4.67129225]
# Iteration 159
# X value is [-4.6778664]
# Iteration 160
# X value is [-4.68430907]
# Iteration 161
# X value is [-4.69062289]
# Iteration 162
# X value is [-4.69681044]
# Iteration 163
# X value is [-4.70287423]
# Iteration 164
# X value is [-4.70881674]
# Iteration 165
# X value is [-4.71464041]
# Iteration 166
# X value is [-4.7203476]
# Iteration 167
# X value is [-4.72594065]
# Iteration 168
# X value is [-4.73142183]
# Iteration 169
# X value is [-4.7367934]
# Iteration 170
# X value is [-4.74205753]
# Iteration 171
# X value is [-4.74721638]
# Iteration 172
# X value is [-4.75227205]
# Iteration 173
# X value is [-4.75722661]
# Iteration 174
# X value is [-4.76208208]
# Iteration 175
# X value is [-4.76684044]
# Iteration 176
# X value is [-4.77150363]
# Iteration 177
# X value is [-4.77607356]
# Iteration 178
# X value is [-4.78055208]
# Iteration 179
# X value is [-4.78494104]
# Iteration 180
# X value is [-4.78924222]
# Iteration 181
# X value is [-4.79345738]
# Iteration 182
# X value is [-4.79758823]
# Iteration 183
# X value is [-4.80163647]
# Iteration 184
# X value is [-4.80560374]
# Iteration 185
# X value is [-4.80949166]
# Iteration 186
# X value is [-4.81330183]
# Iteration 187
# X value is [-4.81703579]
# Iteration 188
# X value is [-4.82069508]
# Iteration 189
# X value is [-4.82428117]
# Iteration 190
# X value is [-4.82779555]
# Iteration 191
# X value is [-4.83123964]
# Iteration 192
# X value is [-4.83461485]
# Iteration 193
# X value is [-4.83792255]
# Iteration 194
# X value is [-4.8411641]
# Iteration 195
# X value is [-4.84434082]
# Iteration 196
# X value is [-4.847454]
# Iteration 197
# X value is [-4.85050492]
# Iteration 198
# X value is [-4.85349482]
# Iteration 199
# X value is [-4.85642493]
# Iteration 200
# X value is [-4.85929643]
# Iteration 201
# X value is [-4.8621105]
# Iteration 202
# X value is [-4.86486829]
# Iteration 203
# X value is [-4.86757092]
# Iteration 204
# X value is [-4.8702195]
# Iteration 205
# X value is [-4.87281511]
# Iteration 206
# X value is [-4.87535881]
# Iteration 207
# X value is [-4.87785164]
# Iteration 208
# X value is [-4.8802946]
# Iteration 209
# X value is [-4.88268871]
# Iteration 210
# X value is [-4.88503494]
# Iteration 211
# X value is [-4.88733424]
# Iteration 212
# X value is [-4.88958755]
# Iteration 213
# X value is [-4.8917958]
# Iteration 214
# X value is [-4.89395989]
# Iteration 215
# X value is [-4.89608069]
# Iteration 216
# X value is [-4.89815907]
# Iteration 217
# X value is [-4.90019589]
# Iteration 218
# X value is [-4.90219198]
# Iteration 219
# X value is [-4.90414814]
# Iteration 220
# X value is [-4.90606517]
# Iteration 221
# X value is [-4.90794387]
# Iteration 222
# X value is [-4.90978499]
# Iteration 223
# X value is [-4.91158929]
# Iteration 224
# X value is [-4.91335751]
# Iteration 225
# X value is [-4.91509036]
# Iteration 226
# X value is [-4.91678855]
# Iteration 227
# X value is [-4.91845278]
# Iteration 228
# X value is [-4.92008372]
# Iteration 229
# X value is [-4.92168205]
# Iteration 230
# X value is [-4.92324841]
# Iteration 231
# X value is [-4.92478344]
# Iteration 232
# X value is [-4.92628777]
# Iteration 233
# X value is [-4.92776201]
# Iteration 234
# X value is [-4.92920677]
# Iteration 235
# X value is [-4.93062264]
# Iteration 236
# X value is [-4.93201019]
# Iteration 237
# X value is [-4.93336998]
# Iteration 238
# X value is [-4.93470258]
# Iteration 239
# X value is [-4.93600853]
# Iteration 240
# X value is [-4.93728836]
# Iteration 241
# X value is [-4.93854259]
# Iteration 242
# X value is [-4.93977174]
# Iteration 243
# X value is [-4.94097631]
# Iteration 244
# X value is [-4.94215678]
# Iteration 245
# X value is [-4.94331365]
# Iteration 246
# X value is [-4.94444737]
# Iteration 247
# X value is [-4.94555842]
# Iteration 248
# X value is [-4.94664726]
# Iteration 249
# X value is [-4.94771431]
# Iteration 250
# X value is [-4.94876002]
# Iteration 251
# X value is [-4.94978482]
# Iteration 252
# X value is [-4.95078913]
# Iteration 253
# X value is [-4.95177335]
# Iteration 254
# X value is [-4.95273788]
# Iteration 255
# X value is [-4.95368312]
# Iteration 256
# X value is [-4.95460946]
# Iteration 257
# X value is [-4.95551727]
# Iteration 258
# X value is [-4.95640692]
# Iteration 259
# X value is [-4.95727879]
# Iteration 260
# X value is [-4.95813321]
# Iteration 261
# X value is [-4.95897055]
# Iteration 262
# X value is [-4.95979113]
# Iteration 263
# X value is [-4.96059531]
# Iteration 264
# X value is [-4.96138341]
# Iteration 265
# X value is [-4.96215574]
# Iteration 266
# X value is [-4.96291262]
# Iteration 267
# X value is [-4.96365437]
# Iteration 268
# X value is [-4.96438128]
# Iteration 269
# X value is [-4.96509366]
# Iteration 270
# X value is [-4.96579178]
# Iteration 271
# X value is [-4.96647595]
# Iteration 272
# X value is [-4.96714643]
# Iteration 273
# X value is [-4.9678035]
# Iteration 274
# X value is [-4.96844743]
# Iteration 275
# X value is [-4.96907848]
# Iteration 276
# X value is [-4.96969691]
# Iteration 277
# X value is [-4.97030297]
# Iteration 278
# X value is [-4.97089691]
# Iteration 279
# X value is [-4.97147898]
# Iteration 280
# X value is [-4.9720494]
# Iteration 281
# X value is [-4.97260841]
# Iteration 282
# X value is [-4.97315624]
# Iteration 283
# X value is [-4.97369312]
# Iteration 284
# X value is [-4.97421925]
# Iteration 285
# X value is [-4.97473487]
# Iteration 286
# X value is [-4.97524017]
# Iteration 287
# X value is [-4.97573537]
# Iteration 288
# X value is [-4.97622066]
# Iteration 289
# X value is [-4.97669625]
# Iteration 290
# X value is [-4.97716232]
# Iteration 291
# X value is [-4.97761908]
# Iteration 292
# X value is [-4.97806669]
# Iteration 293
# X value is [-4.97850536]
# Iteration 294
# X value is [-4.97893525]
# Iteration 295
# X value is [-4.97935655]
# Iteration 296
# X value is [-4.97976942]
# Iteration 297
# X value is [-4.98017403]
# Iteration 298
# X value is [-4.98057055]
# Iteration 299
# X value is [-4.98095914]
# Iteration 300
# X value is [-4.98133995]
# Iteration 301
# X value is [-4.98171316]
# Iteration 302
# X value is [-4.98207889]
# Iteration 303
# X value is [-4.98243731]
# Iteration 304
# X value is [-4.98278857]
# Iteration 305
# X value is [-4.9831328]
# Iteration 306
# X value is [-4.98347014]
# Iteration 307
# X value is [-4.98380074]
# Iteration 308
# X value is [-4.98412472]
# Iteration 309
# X value is [-4.98444223]
# Iteration 310
# X value is [-4.98475338]
# Iteration 311
# X value is [-4.98505832]
# Iteration 312
# X value is [-4.98535715]
# Iteration 313
# X value is [-4.98565001]
# Iteration 314
# X value is [-4.98593701]
# Iteration 315
# X value is [-4.98621827]
# Iteration 316
# X value is [-4.9864939]
# Iteration 317
# X value is [-4.98676402]
# Iteration 318
# X value is [-4.98702874]
# Iteration 319
# X value is [-4.98728817]
# Iteration 320
# X value is [-4.9875424]
# Iteration 321
# X value is [-4.98779156]
# Iteration 322
# X value is [-4.98803573]
# Iteration 323
# X value is [-4.98827501]
# Iteration 324
# X value is [-4.98850951]
# Iteration 325
# X value is [-4.98873932]
# Iteration 326
# X value is [-4.98896453]
# Iteration 327
# X value is [-4.98918524]
# Iteration 328
# X value is [-4.98940154]
# Iteration 329
# X value is [-4.98961351]
# Iteration 330
# X value is [-4.98982124]
# Iteration 331
# X value is [-4.99002481]
# Iteration 332
# X value is [-4.99022432]
# Iteration 333
# X value is [-4.99041983]
# Iteration 334
# X value is [-4.99061143]
# Iteration 335
# X value is [-4.99079921]
# Iteration 336
# X value is [-4.99098322]
# Iteration 337
# X value is [-4.99116356]
# Iteration 338
# X value is [-4.99134029]
# Iteration 339
# X value is [-4.99151348]
# Iteration 340
# X value is [-4.99168321]
# Iteration 341
# X value is [-4.99184955]
# Iteration 342
# X value is [-4.99201256]
# Iteration 343
# X value is [-4.9921723]
# Iteration 344
# X value is [-4.99232886]
# Iteration 345
# X value is [-4.99248228]
# Iteration 346
# X value is [-4.99263264]
# Iteration 347
# X value is [-4.99277998]
# Iteration 348
# X value is [-4.99292438]
# Iteration 349
# X value is [-4.9930659]
# Iteration 350
# X value is [-4.99320458]
# Iteration 351
# X value is [-4.99334049]
# Iteration 352
# X value is [-4.99347368]
# Iteration 353
# X value is [-4.9936042]
# Iteration 354
# X value is [-4.99373212]
# Iteration 355
# X value is [-4.99385748]
# Iteration 356
# X value is [-4.99398033]
# Iteration 357
# X value is [-4.99410072]
# Iteration 358
# X value is [-4.99421871]
# Iteration 359
# X value is [-4.99433433]
# Iteration 360
# X value is [-4.99444764]
# Iteration 361
# X value is [-4.99455869]
# Iteration 362
# X value is [-4.99466752]
# Iteration 363
# X value is [-4.99477417]
# Iteration 364
# X value is [-4.99487868]
# Iteration 365
# X value is [-4.99498111]
# Iteration 366
# X value is [-4.99508149]
# Iteration 367
# X value is [-4.99517986]
# Iteration 368
# X value is [-4.99527626]
# Iteration 369
# X value is [-4.99537074]
# Iteration 370
# X value is [-4.99546332]
# Iteration 371
# X value is [-4.99555406]
# Iteration 372
# X value is [-4.99564297]
# Iteration 373
# X value is [-4.99573011]
# Iteration 374
# X value is [-4.99581551]
# Iteration 375
# X value is [-4.9958992]
# Iteration 376
# X value is [-4.99598122]
# Iteration 377
# X value is [-4.99606159]
# Iteration 378
# X value is [-4.99614036]
# Iteration 379
# X value is [-4.99621755]
# Iteration 380
# X value is [-4.9962932]
# Iteration 381
# X value is [-4.99636734]
# Iteration 382
# X value is [-4.99643999]
# Iteration 383
# X value is [-4.99651119]
# Iteration 384
# X value is [-4.99658097]
# Iteration 385
# X value is [-4.99664935]
# Iteration 386
# X value is [-4.99671636]
# Iteration 387
# X value is [-4.99678204]
# Iteration 388
# X value is [-4.99684639]
# Iteration 389
# X value is [-4.99690947]
# Iteration 390
# X value is [-4.99697128]
# Iteration 391
# X value is [-4.99703185]
# Iteration 392
# X value is [-4.99709121]
# Iteration 393
# X value is [-4.99714939]
# Iteration 394
# X value is [-4.9972064]
# Iteration 395
# X value is [-4.99726227]
# Iteration 396
# X value is [-4.99731703]
# Iteration 397
# X value is [-4.99737069]
# Iteration 398
# X value is [-4.99742327]
# Iteration 399
# X value is [-4.99747481]
# Iteration 400
# X value is [-4.99752531]
# Iteration 401
# X value is [-4.99757481]
# Iteration 402
# X value is [-4.99762331]
# Iteration 403
# X value is [-4.99767084]
# Iteration 404
# X value is [-4.99771743]
# Iteration 405
# X value is [-4.99776308]
# Iteration 406
# X value is [-4.99780782]
# Iteration 407
# X value is [-4.99785166]
# Iteration 408
# X value is [-4.99789463]
# Iteration 409
# X value is [-4.99793674]
# Iteration 410
# X value is [-4.997978]
# Iteration 411
# X value is [-4.99801844]
# Iteration 412
# X value is [-4.99805807]
# Iteration 413
# X value is [-4.99809691]
# Iteration 414
# X value is [-4.99813497]
# Iteration 415
# X value is [-4.99817227]
# Iteration 416
# X value is [-4.99820883]
# Iteration 417
# X value is [-4.99824465]
# Iteration 418
# X value is [-4.99827976]
# Iteration 419
# X value is [-4.99831416]
# Iteration 420
# X value is [-4.99834788]
# Iteration 421
# X value is [-4.99838092]
# Iteration 422
# X value is [-4.9984133]
# Iteration 423
# X value is [-4.99844504]
# Iteration 424
# X value is [-4.99847614]
# Iteration 425
# X value is [-4.99850661]
# Iteration 426
# X value is [-4.99853648]
# Iteration 427
# X value is [-4.99856575]
# Iteration 428
# X value is [-4.99859444]
# Iteration 429
# X value is [-4.99862255]
# Iteration 430
# X value is [-4.9986501]
# Iteration 431
# X value is [-4.9986771]
# Iteration 432
# X value is [-4.99870355]
# Iteration 433
# X value is [-4.99872948]
# Iteration 434
# X value is [-4.99875489]
# Iteration 435
# X value is [-4.99877979]
# Iteration 436
# X value is [-4.9988042]
# Iteration 437
# X value is [-4.99882811]
# Iteration 438
# X value is [-4.99885155]
# Iteration 439
# X value is [-4.99887452]
# Iteration 440
# X value is [-4.99889703]
# Iteration 441
# X value is [-4.99891909]
# Iteration 442
# X value is [-4.99894071]
# Iteration 443
# X value is [-4.99896189]
# Iteration 444
# X value is [-4.99898266]
# Iteration 445
# X value is [-4.999003]
# Iteration 446
# X value is [-4.99902294]
# Iteration 447
# X value is [-4.99904248]
# Iteration 448
# X value is [-4.99906163]
# Iteration 449
# X value is [-4.9990804]
# Iteration 450
# X value is [-4.99909879]
# Iteration 451
# X value is [-4.99911682]
# Iteration 452
# X value is [-4.99913448]
# Iteration 453
# X value is [-4.99915179]
# Iteration 454
# X value is [-4.99916876]
# Iteration 455
# X value is [-4.99918538]
# Iteration 456
# X value is [-4.99920167]
# Iteration 457
# X value is [-4.99921764]
# Iteration 458
# X value is [-4.99923329]
# Iteration 459
# X value is [-4.99924862]
# Iteration 460
# X value is [-4.99926365]
# Iteration 461
# X value is [-4.99927838]
# Iteration 462
# X value is [-4.99929281]
# Iteration 463
# X value is [-4.99930695]
# Iteration 464
# X value is [-4.99932081]
# Iteration 465
# X value is [-4.9993344]
# Iteration 466
# X value is [-4.99934771]
# Iteration 467
# X value is [-4.99936076]
# Iteration 468
# X value is [-4.99937354]
# Iteration 469
# X value is [-4.99938607]
# Iteration 470
# X value is [-4.99939835]
# Iteration 471
# X value is [-4.99941038]
# Iteration 472
# X value is [-4.99942217]
# Iteration 473
# X value is [-4.99943373]
# Iteration 474
# X value is [-4.99944506]
# Iteration 475
# X value is [-4.99945615]
# Iteration 476
# X value is [-4.99946703]
# Iteration 477
# X value is [-4.99947769]
# Iteration 478
# X value is [-4.99948814]
# Iteration 479
# X value is [-4.99949837]
# Iteration 480
# X value is [-4.99950841]
# Iteration 481
# X value is [-4.99951824]
# Iteration 482
# X value is [-4.99952787]
# Iteration 483
# X value is [-4.99953732]
# Iteration 484
# X value is [-4.99954657]
# Iteration 485
# X value is [-4.99955564]
# Iteration 486
# X value is [-4.99956453]
# Iteration 487
# X value is [-4.99957323]
# Iteration 488
# X value is [-4.99958177]
# Iteration 489
# X value is [-4.99959013]
# Iteration 490
# X value is [-4.99959833]
# Iteration 491
# X value is [-4.99960637]
# Iteration 492
# X value is [-4.99961424]
# Iteration 493
# X value is [-4.99962195]
# Iteration 494
# X value is [-4.99962951]
# Iteration 495
# X value is [-4.99963692]
# Iteration 496
# X value is [-4.99964419]
# Iteration 497
# X value is [-4.9996513]
# Iteration 498
# X value is [-4.99965828]
# Iteration 499
# X value is [-4.99966511]
# Iteration 500
# X value is [-4.99967181]
# Iteration 501
# X value is [-4.99967837]
# Iteration 502
# X value is [-4.9996848]
# Iteration 503
# X value is [-4.99969111]
# Iteration 504
# X value is [-4.99969729]
# Iteration 505
# X value is [-4.99970334]
# Iteration 506
# X value is [-4.99970927]
# Iteration 507
# X value is [-4.99971509]
# Iteration 508
# X value is [-4.99972079]
# Iteration 509
# X value is [-4.99972637]
# Iteration 510
# X value is [-4.99973184]
# Iteration 511
# X value is [-4.99973721]
# Iteration 512
# X value is [-4.99974246]
# Iteration 513
# X value is [-4.99974761]
# Iteration 514
# X value is [-4.99975266]
# Iteration 515
# X value is [-4.99975761]
# Iteration 516
# X value is [-4.99976246]
# Iteration 517
# X value is [-4.99976721]
# Iteration 518
# X value is [-4.99977186]
# Iteration 519
# X value is [-4.99977642]
# Iteration 520
# X value is [-4.9997809]
# Iteration 521
# X value is [-4.99978528]
# Iteration 522
# X value is [-4.99978957]
# Iteration 523
# X value is [-4.99979378]
# Iteration 524
# X value is [-4.99979791]
# Iteration 525
# X value is [-4.99980195]
# Iteration 526
# X value is [-4.99980591]
# Iteration 527
# X value is [-4.99980979]
# Iteration 528
# X value is [-4.99981359]
# Iteration 529
# X value is [-4.99981732]
# Iteration 530
# X value is [-4.99982098]
# Iteration 531
# X value is [-4.99982456]
# Iteration 532
# X value is [-4.99982807]
# Iteration 533
# X value is [-4.9998315]
# Iteration 534
# X value is [-4.99983487]
# Iteration 535
# X value is [-4.99983818]
# Iteration 536
# X value is [-4.99984141]
# Iteration 537
# X value is [-4.99984459]
# Iteration 538
# X value is [-4.99984769]
# Iteration 539
# X value is [-4.99985074]
# Iteration 540
# X value is [-4.99985372]
# Iteration 541
# X value is [-4.99985665]
# Iteration 542
# X value is [-4.99985952]
# Iteration 543
# X value is [-4.99986233]
# Iteration 544
# X value is [-4.99986508]
# Iteration 545
# X value is [-4.99986778]
# Iteration 546
# X value is [-4.99987042]
# Iteration 547
# X value is [-4.99987301]
# Iteration 548
# X value is [-4.99987555]
# Iteration 549
# X value is [-4.99987804]
# Iteration 550
# X value is [-4.99988048]
# Iteration 551
# X value is [-4.99988287]
# Iteration 552
# X value is [-4.99988522]
# Iteration 553
# X value is [-4.99988751]
# Iteration 554
# X value is [-4.99988976]
# Iteration 555
# X value is [-4.99989197]
# Iteration 556
# X value is [-4.99989413]
# Iteration 557
# X value is [-4.99989624]
# Iteration 558
# X value is [-4.99989832]
# Iteration 559
# X value is [-4.99990035]
# Iteration 560
# X value is [-4.99990235]
# Iteration 561
# X value is [-4.9999043]
# Iteration 562
# X value is [-4.99990621]
# Iteration 563
# X value is [-4.99990809]
# Iteration 564
# X value is [-4.99990993]
# Iteration 565
# X value is [-4.99991173]
# Iteration 566
# X value is [-4.99991349]
# Iteration 567
# X value is [-4.99991522]
# Iteration 568
# X value is [-4.99991692]
# Iteration 569
# X value is [-4.99991858]
# Iteration 570
# X value is [-4.99992021]
# Iteration 571
# X value is [-4.9999218]
# Iteration 572
# X value is [-4.99992337]
# Iteration 573
# X value is [-4.9999249]
# Iteration 574
# X value is [-4.9999264]
# Iteration 575
# X value is [-4.99992788]
# Iteration 576
# X value is [-4.99992932]
# Iteration 577
# X value is [-4.99993073]
# Iteration 578
# X value is [-4.99993212]
# Iteration 579
# X value is [-4.99993347]
# Iteration 580
# X value is [-4.99993481]
# Iteration 581
# X value is [-4.99993611]
# Iteration 582
# X value is [-4.99993739]
# Iteration 583
# X value is [-4.99993864]
# Iteration 584
# X value is [-4.99993987]
# Iteration 585
# X value is [-4.99994107]
# Iteration 586
# X value is [-4.99994225]
# Iteration 587
# X value is [-4.9999434]
# Iteration 588
# X value is [-4.99994453]
# Iteration 589
# X value is [-4.99994564]
# Iteration 590
# X value is [-4.99994673]
# Iteration 591
# X value is [-4.9999478]
# Iteration 592
# X value is [-4.99994884]
# Iteration 593
# X value is [-4.99994986]
# Iteration 594
# X value is [-4.99995087]
# Iteration 595
# X value is [-4.99995185]
# The local minimum occurs at [-4.99995185]
